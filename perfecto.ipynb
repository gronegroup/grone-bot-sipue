# %% [markdown]
# # Importar bibliotecas necesarias
# En este notebook no se requieren librerías externas para imprimir un mensaje simple.

# %% [markdown]
# ## Imprimir '¡Perfecto!' en pantalla
# A continuación, se imprime el mensaje solicitado.

# %%
print('¡Perfecto!')
